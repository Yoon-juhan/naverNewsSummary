# %%
###################
#   요약  테스트   #
################### 
import pandas as pd

# coding: utf-8

# 만든 기능 임포트
from crawling import UrlCrawling, ContentCrawling
from preprocessing import Preprocessing
from clustering import Clustering
from summary import Summary
from database import insert, select
from tts import tts

article_df = pd.read_csv("csv/유사도측정.csv")
article_df['nouns'] = article_df['nouns'].apply(lambda x: eval(x))        # 명사 열을 다시 리스트 형식으로 변환

article_df['content'] = article_df['content'].apply(lambda x: Preprocessing.clean(x))
article_df['title'] = article_df['title'].apply(lambda x: Preprocessing.clean(x))

vector_list = Preprocessing.getVector(article_df)                               # 명사 벡터화

Clustering.addClusterNumber(article_df, vector_list)                            # 군집 번호 열 생성
cluster_counts_df = Clustering.getClusteredArticle(article_df)                  # 군집 개수 카운트한 df

summary_article = Summary.getSummaryArticle(article_df, cluster_counts_df)              # 요약한 기사 데이터 프레임 반환
summary_article = Preprocessing.convertCategory(summary_article)

###################
#   요약  테스트   #
###################
# Out:
# 60 = 이순신 아껴쓰면 안 된다 與 한동훈 비대위 사실상 확정
# 60 = 정의찬 엄호나선 민형배 부적격은 검증위 권한 남용
# 60 = 한미일 '北 ICBM 대응' 공중훈련 美 B1B 폭격기 참가
# 60 = 김종인 "한동훈 '별의 순간' 아직등판 빠르다"
# 60 = 조정훈 "尹아바타?인간 한동훈을 몰라도 너무 몰라"
# 60 = 한동훈 비대위 두 갈래 길총선 승리 박근혜냐, 참패 황교안이냐
# 60 = SNS에서 국민의힘 겨냥 불임정당 표현 野 민형배황급히 글 삭제
# 60 = 與 '비대위 의견 청취' 마무리...김부겸, 이재명에 "이낙연 만나야"
# 60 = 한동훈 '몰카 공작' 발언에..."김건희 명품백 받은 건 팩트 아닌가"
# 60 = 檢 출신 황교안의 조언 "한동훈 막 써버리면 안돼나도 당대표 나갔을 때"
# 60 = 작년 억대 연봉자 131만명 넘어1인당 평균은 만원
# 60 = 'HMM 인수' 우협 선정된 하림, 이틀 연속 '上上'
# 60 = 증시에 불어오는 훈풍석 달 만에 코스피 2600 회복
# 60 = 태영건설 위기설에 지주사, 추가 지분 매각으로 유동성 확보 나설까
# 60 = 은평구 재개발 최대어 '대조1구역' 공사중단 위기현대건설 통보 예정
# 60 = 현대건설, 은평구 대조1구역 공사 중단 가능성 커져
# 60 =  코스피, 美 산타랠리 타고 3개월 만에 2600선 탈환
# 60 = 포스코, 정기 임원 인사 단행주요 그룹사 사장단 인사는 미뤄
# 60 = "알리, 테무 아직 안 써봤니?" 쇼핑대신 사야할 이 종목
# 60 = '호황 끝 위기'금융지주 인사, '안정'에 쏠린 이유
# 60 =  한파 속 설악산 갔다가산악회원 2명 숨진 채 발견
# 60 = 빙판길 교통사고 잇따라송파대로·올림픽대로 부분통제
# 60 = 올해는 화이트 크리스마스? 25일 중부지방 눈 내릴 수도
# 60 = 신난다 하얀 눈이 좋은 푸바오 한국서 마지막 겨울나기
# 60 = 지난해 육아휴직 부모 19만9976명 '육아하는 아빠' 29 늘었다
# 60 = 이태원 유가족들의 '눈밭 오체투지'... "묻고 싶다, 밝혀진 게 뭔가"
# 60 = "2억 보내라" 40대가 초등생 납치아이 테이프 끊고 1시간만에 탈출(종합)
# 60 = 경복궁 낙서 10대 연인의 범행 동기는 아직 물음표···대체 어떤 지인이?
# 60 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 70 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 80 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 90 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 100 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 110 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 120 = 내일 아침 영하 15도로 뚝서울시 한파 비상체계 가동
# 60 = 민형배 "민주당 기준 조선일보 아니다"정의찬 '부적격' 판단 비판
# 60 = 매일 쓰는 텀블러 안 씻고 그냥 쓰다 병원行 美 여성 사연 공개
# 60 = 아직도 집사에요? 묻는 교회 문화, 정말 괜찮은지?
# 60 =  북극발 최강 한파에 전국 한파특보...서해안 대설특보
# 60 = 내일 영하 19도 '북극 한파' 습격화이트 크리스마스 가능성도
# 60 = 인천공항 코로나 딛고 4년 만에 흑자 전환...국제여객은 내년 100 회복
# 60 = 한국앤컴퍼니 투자자들, MBK에 현혹되지 않아야
# 60 =  동장군 맹위내일 올겨울 들어 가장 춥다
# 60 = 세대별 선호하는 숙취해소제는?
# 60 = 내일부터 역대급 추위 충청 이남 모레까지 폭설
# 60 = 현대차그룹, 역대 최대 252명 임원 승진신규 38가 40대
# 60 = 잘못된 원전 투자, 경영진 도덕적 해이日 도시바 쓸쓸한 상장폐지
# 60 = 설마 야경 구경하자는 위험천만 화산폭발 관광객가스, 수도 레이캬비크 등 도시 덮칠 수도
# 60 = "반란 가담 트럼프, 대선출마 금지"'피선거권 박탈' 첫 판결
# 60 = 시진핑 中주석, 마오 탄생 130주년 맞춰 기념당 참배할 듯
# 60 = 글로벌 빅7 홍해 운송 중단세계경제 복병으로
# 60 = 중도 사퇴는 없다대만 대선후보 커원저, 지지율 꼴찌에도 완주 다짐
# 60 = 2년 전 엉망진창 베를린 총선"재선거하라" 초유의 헌재 결정
# 60 = 日도시바 상장폐지74년 상장 역사 막 내려
# 60 = '크리스마스 휴전' 가능할까? "이스라엘, 일주일 휴전 제안"
# 60 = 일본, 미국에 패트리엇 제공해 우크라 간접지원살상무기 첫 수출
# 60 = 삼성 반도체 성적 부진에 성과급도 '뚝'...메모리 12.5, 파운드리 0
# 60 = 트랙 위를 '껑충껑충'...카이스트 로봇이 세운 세계 기록
# 60 = 100→0 뚝...삼성전자 반도체 부문 성과급 쇼크
# 60 = "IPTV가 날 알아본다"...SKB, AI 미디어 서비스 쏟아냈다
# 60 = 탈화석연료 합의 며칠 됐다고석유 시출권 경매하는 미국
# 60 = 넥스트 테슬라 절반 일년 내 현금 바닥 '시한폭탄'
# 60 = 뜨겁게 달궜던 2023년 스타트업 법무 이슈
# 60 = 美 애플워치 판매중단, 전체 매출에 얼마나 영향 줄까
# 60 = 한국은행 "내년말 물가상승률 2까지 하락"
# 60 = 한국인, 유튜브 월평균  998억분 봤다카톡의 약 3배
# 60 = 이동욱의 위험한 유산'킬러들의 쇼핑몰' 김혜준, 티저 포스터 공개
# 60 = "아낌없는 지원"정혜성,빅픽처이앤티와 전속계약
# 60 = 최강창민 "예명 창피할 때 있지만그걸로 많이 벌어" 솔직 (비보티비)
# 60 = 나는 솔로 승자는 16기 순자? 내가 웃는 이유 공개 열애
# 60 = 박나래 성대 폴립 수술 두 번요 근래 은퇴 고민도
# 60 = 환상연가 박지훈황희김태우, 엇갈린 운명의 세 부자
# 60 = 마약 꼬리표 뗀 지드래곤, 첫 회견인 이유
# 60 = "14kg 증량→1년 동안 사투리 연습" 장동윤×이주명의 씨름 로맨스 '모래에도 꽃이 핀다'
# 60 = "없던 추억도 만들어져"2011년생 아역배우, god 팬심 고백
# 60 = 주현영, 이렇게 청순했나크롭 니트 입고 순수 매력
# 60 = 대한체육회 등 체육단체, 국가스포츠정책위원회 관련 성명서 발표
# 60 = 해마다 늘어나는 청소년 도박...불법도박 근절의 중요성
# 60 = 높이뛰기 우상혁, 내년 4월부터 다이아몬드리그 2연패 시동
# 60 = 국가스포츠정책위 시작부터 삐걱체육계, 정부 일방통행에 유감
# 60 = '100점 만점' 체육진흥공단, '가족친화 인증' 공공기관 '톱10'으로 선정돼
# 60 = 국민체육진흥공단, 2023 가족친화 인증심사 우수기관 선정
# 60 = 데뷔전서 '투신' 김재웅 꺾었던 '코브라' 샤밀 가사노프, 한국 선수 또 이길까...오호택과 맞대결
# 60 = 괌 사이클 대회서 한국 참가 선수, 우승 싹쓸이
# 60 = 16세 천재 바둑소녀 김은지, 최연소·최단기 9단 등극
# 60 = 홀란 BBC 올해의 스포츠 스타 트레블 맨시티, 세계챔피언도 코앞
